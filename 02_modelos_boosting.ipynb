# %% [markdown]
# ## 5. Modelagem - Boosting

# %% [markdown]
# Etapa 1 - Importando a base já trabalhada

# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import QuantileTransformer, StandardScaler, OneHotEncoder
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from utils import functions

# %%
# Carregando a abt
with open('./artefatos/ABT/abt.pkl', mode= 'rb') as f:
    abt = pickle.load(f)

# %% [markdown]
# Etapa 2 - Fazendo o split
# * Separando 20% dos dados para teste
# * Mantendo a taxa de evento original do problema

# %%
# Separando o target da base
X = abt.drop(columns=['class'])
y = abt['class']
del(abt)

# %%
from sklearn.model_selection import train_test_split

# Fazendo o Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2,random_state= 1,stratify= y)

# Checando os shapes
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (48000, 170) (48000,)
# (12000, 170) (12000,)

# %% [markdown]
# Etapa 3 - Data Preparation
#
# > Pipeline: Numéricos
# * Inputando mediana para missings
# * Transformação por quartis
# * Escalonamento por padronização
#
# > Pipeline: Categóricos (cluster e anomaly)
# * Inputando a moda
# * One Hot Encoding
#
# > Salvar o Artefato

# %%
# Separando as variáveis numéricas
dp_boost_num_vars = X.select_dtypes(exclude= 'object').columns

# Separando as variáveis categóricas
dp_boost_cat_vars = X.select_dtypes(include= 'object').columns

# Armazenando o index
train_idx, test_idx = X_train.index, X_test.index

# Pipeline: Vars. Numéricas
dp_boost_num_pipeline = Pipeline([
    ('dp_boost_num_inputer', SimpleImputer(strategy='median')),
    ('dp_boost_num_transformer', QuantileTransformer(random_state= 1)),
    ('dp_boost_num_scaler', StandardScaler())
])

# Pipeline. Vars. Categóricas
dp_boost_cat_pipeline = Pipeline([
    ('dp_boost_cat_inputer', SimpleImputer(strategy= 'most_frequent')),
    ('dp_boost_cat_encoder', OneHotEncoder(sparse_output= False, drop= 'first', dtype= np.int8))
])

# Montando o Transformador
dp_boost_preprocessor = ColumnTransformer([
    ('num_pipeline', dp_boost_num_pipeline, dp_boost_num_vars),
    ('cat_pipeline', dp_boost_cat_pipeline, dp_boost_cat_vars)
])

# Configurando a Pipeline
dp_boost_pipeline = Pipeline(
    steps= [('preprocessor', dp_boost_preprocessor)]
)

# %%
# Ajustando o pipeline aos dados de Treino
dp_boost_pipeline = dp_boost_pipeline.fit(X_train, y_train)

# Pegando o nome das features do One Hot Enconder
dp_boost_cat_vars = dp_boost_pipeline.named_steps['preprocessor'].named_transformers_['cat_pipeline'].named_steps['dp_boost_cat_encoder'].get_feature_names_out(dp_boost_cat_vars)

# Juntando as variáveis categóricas e numéricas
dp_boost_vars = list(dp_boost_num_vars) + list(dp_boost_cat_vars)

# Transformando os dados de Treino
X_train_boosting = pd.DataFrame(data = dp_boost_pipeline.transform(X_train), columns= dp_boost_vars, index= train_idx)

# Transformando os dados de Teste
X_test_boosting = pd.DataFrame(data = dp_boost_pipeline.transform(X_test), columns= dp_boost_vars, index= test_idx)

# %%
with open('./artefatos/Boosting/pipeline.pkl', mode= 'wb') as file:
    pickle.dump(dp_boost_pipeline, file)

# %%
features = X_train_boosting.columns.to_list()
with open('./artefatos/Boosting/pipeline_feature_names_out.pkl', mode= 'wb') as file:
    pickle.dump(features, file)

# %% [markdown]
# Etapa 4 - Feature Selection
#
# * Removendo Features com Alta Correlação
# * Removendo Features com baixa variância
# * Removendo Features via RFE

# %%
# Remoção por Correlação - Aplicando nos conjuntos de treino e teste
X_train_boosting_fs, fs_corr_vars_to_drop = functions.remove_highly_correlated_features(
    df= X_train_boosting,
    threshold= 0.6
)

X_test_boosting_fs = X_test_boosting.drop(columns= fs_corr_vars_to_drop)

assert (X_train_boosting_fs.columns == X_test_boosting_fs.columns).all()

# %%
# Remoção por Variância - Aplicando nos conjuntos de treino e teste
var_fs = VarianceThreshold().fit(X_train_boosting_fs)

fs_VAR_vars_to_drop = X_train_boosting_fs.loc[:, ~var_fs.get_support()].columns.to_list()

# Aplicando ao conjunto de treino
X_train_boosting_fs = X_train_boosting_fs.drop(columns= fs_VAR_vars_to_drop)

# Aplicando ao conjunto de teste
X_test_boosting_fs = X_test_boosting_fs.drop(columns= fs_VAR_vars_to_drop)

# Verificando se os conjuntos de treino e teste possuem as mesmas colunas
assert (X_train_boosting_fs.columns == X_test_boosting_fs.columns).all()

# %%
# Salvando as colunas selecionadas pós feature selection
selected_features = X_train_boosting_fs.columns.to_list()

# %% [markdown]
# Etapa 4 - Teste de Modelo Pós Data Preparation
#
# > Testar os seguintes modelos:
#
# * GradientBoosting
# * Light GBM
# * XGBoost

# %% [markdown]
# > Para avaliar os modelos de forma que faça sentido para o negócio, não podemos levar em consideração apenas uma métrica em específico. Isso porque busca-se o cenário em que a empresa tenha o menor custo possível com as manutenções. Segundo as instruções da empresa, temos que:
#
#
# 1. Se um caminhão é mandado para manutenção, porém não possui um defeito, será cobrado $10
#
# 2. Se um caminhão é mandado para manutenção, e possui um defeito, será cobrado $25
#
# 3. Se um caminhão não é mandado para manutenção, e possui um defeito, será cobrado $500
#
#
# > Observando o cenário acima, fica claro que existe uma preocupação muito grande com Falsos Negativos (FN), uma vez que seu custo é 20 vezes o de um Verdadeiro Positivo (TP), e 50 vezes o de um Falso Positivo (FP). Dessa forma, podemos criar uma função de custo (Loss Function) padronizada para avaliar o modelo aos olhos no negócio da seguinte maneira:
#
#
# $$C_{total} = (FP \times V_{FP}) + (TP \times V_{TP}) + (FN \times V_{FN})$$
#
# Onde $V$ indica o valor associado ao tipo de erro subscrito.
#
# Logo, para o nosso problema, temos que:
#
# $$C_{total} = (FP \times 10) + (TP \times 25) + (FN \times 500)$$

# %%
# Testando os Modelos
models = [
    GradientBoostingClassifier(random_state=1),
    XGBClassifier(random_state=1, n_jobs=-1),
    LGBMClassifier(random_state=1, n_jobs=-1)
]

for model in models:
    model_name = str(model)[:str(model).find("(")]
    # Treinamento
    model.fit(X_train_boosting_fs, y_train)

    # Avaliação
    metrics = functions.calculate_metrics(model_name, model, X_train_boosting_fs, y_train, X_test_boosting_fs, y_test)
    display(metrics)

    custo = functions.loss_function(y_test, model.predict(X_test_boosting_fs))
    print(f'Modelo: {model_name} // Custo: {custo}')
# Out:
#                     Algoritmo Conjunto  Acuracia  Precisao  Recall   AUC_ROC  \
# 0  GradientBoostingClassifier   Treino  0.994396  0.899248  0.7475  0.990072
# 1  GradientBoostingClassifier    Teste  0.991083  0.756906  0.6850  0.980002
#
#        GINI        KS
# 0  0.980143  0.923199
# 1  0.960004  0.903475
# Modelo: GradientBoostingClassifier // Custo: 35365
#        Algoritmo Conjunto  Acuracia  Precisao   Recall   AUC_ROC      GINI  \
# 0  XGBClassifier   Treino  0.999646  1.000000  0.97875  0.999951  0.999902
# 1  XGBClassifier    Teste  0.992500  0.816092  0.71000  0.981223  0.962445
#
#          KS
# 0  0.996081
# 1  0.903983
# Modelo: XGBClassifier // Custo: 32870
# [LightGBM] [Info] Number of positive: 800, number of negative: 47200
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6170
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.016667 -> initscore=-4.077537
# [LightGBM] [Info] Start training from score -4.077537
#         Algoritmo Conjunto  Acuracia  Precisao   Recall   AUC_ROC      GINI  \
# 0  LGBMClassifier   Treino  0.999500  0.996164  0.97375  0.999987  0.999975
# 1  LGBMClassifier    Teste  0.992667  0.833333  0.70000  0.976168  0.952336
#
#          KS
# 0  0.999131
# 1  0.915339
# Modelo: LGBMClassifier // Custo: 33780

# %% [markdown]
# Etapa 5 - Tunning Hiperparâmetros e Cross Validation
#
# > Tunar os seguintes modelos, levando em consideração a função de custo:
#
# * GradientBoosting
# * Light GBM
# * XGBoost

# %% [markdown]
# > Light GBM

# %%
import optuna
from sklearn.model_selection import StratifiedKFold

EARLY_STOPPING = 15

class EarlyStoppingExceeded(optuna.exceptions.OptunaError):
    early_stop = EARLY_STOPPING
    early_stop_count = 0
    best_score = None

def early_stopping_opt(study, trial):
    if EarlyStoppingExceeded.best_score == None:
      EarlyStoppingExceeded.best_score = study.best_value

    if study.best_value < EarlyStoppingExceeded.best_score:
        EarlyStoppingExceeded.best_score = study.best_value
        EarlyStoppingExceeded.early_stop_count = 0
    else:
      if EarlyStoppingExceeded.early_stop_count > EarlyStoppingExceeded.early_stop:
            EarlyStoppingExceeded.early_stop_count = 0
            best_score = None
            raise EarlyStoppingExceeded()
      else:
            EarlyStoppingExceeded.early_stop_count=EarlyStoppingExceeded.early_stop_count+1
    return

def objective(trial):
    # Var. de controle da métrica
    avg_loss_func = 0

    # Criando os parametros a serem testados
    params = {
        "objective": "binary",
        "metric": "auc",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 20.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 20.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.05, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.05, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 10),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "learning_rate": trial.suggest_float("learning_rate", 1e-4, 1e-1, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 20),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 1000),
        "max_bin": trial.suggest_int("max_bin", 100, 1000),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "subsample_freq": trial.suggest_int("subsample_freq", 1, 10),
        "min_split_gain": trial.suggest_float("min_split_gain", 0.0, 1.0)
    }

    # Fazendo os Splits (Cross Validation)
    cv = StratifiedKFold(n_splits= 5, random_state= 1, shuffle= True)

    for train_idx, validation_idx in cv.split(X_train, y_train):
        # Instancia o Modelo
        model = LGBMClassifier(**params, random_state= 1, n_jobs= -1)

        # Vars Preditoras - Treino
        X_train_cv = X_train.iloc[train_idx]

        # Vars Preditoras - Validação
        X_validation_cv = X_train.iloc[validation_idx]

        # Target - Treino
        y_train_cv = y_train.iloc[train_idx]

        # Target - Validação
        y_validation_cv = y_train.iloc[validation_idx]

        # Aplicando o DATAPREP nos conjuntos de Treino
        X_train_cv_processed = pd.DataFrame(
            data = dp_boost_pipeline.fit_transform(X_train_cv, y_train_cv),
            columns = dp_boost_vars # Lista de variáveis que saem do pipeline na etapa de dataprep
        )[selected_features] # Filtrando apenas as features da etapa de feature selection

        # Aplicando o DATAPREP nos conjuntos de Validação
        X_validation_cv_processed = pd.DataFrame(
            data = dp_boost_pipeline.transform(X_validation_cv),
            columns= dp_boost_vars
        )[selected_features]

        # Treinando o Modelo
        model.fit(X_train_cv_processed, y_train_cv)

        # Fazendo as predições
        y_pred = model.predict(X_validation_cv_processed)

        avg_loss_func += functions.loss_function(y_validation_cv, y_pred)
    
    return avg_loss_func/5

study = optuna.create_study(
    direction= 'minimize',
    study_name= 'LGBM_v01',
    storage= 'sqlite:///LGBM_v01.db'
)

try:
    study.optimize(objective, timeout=7200, callbacks= [early_stopping_opt])

except EarlyStoppingExceeded:
    print(f'Sem novas melhorias a partir da iteração {len(study.trials)}')

best = study.best_trial

print(f'Melhor score: {best.value}')
# Out:
# [I 2024-07-12 17:48:43,329] A new study created in RDB with name: LGBM_v01
# [I 2024-07-12 17:48:51,929] Trial 0 finished with value: 80000.0 and parameters: {'lambda_l1': 8.26578265308799e-07, 'lambda_l2': 0.8979220317570481, 'num_leaves': 212, 'feature_fraction': 0.7482983220747398, 'bagging_fraction': 0.41361673046197533, 'bagging_freq': 1, 'min_child_samples': 57, 'learning_rate': 0.0030831359239263303, 'max_depth': 20, 'min_data_in_leaf': 131, 'max_bin': 206, 'subsample': 0.694814856370432, 'colsample_bytree': 0.5679566074579296, 'subsample_freq': 6, 'min_split_gain': 0.7274415161160845}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 17:49:00,739] Trial 1 finished with value: 30076.0 and parameters: {'lambda_l1': 6.845658675102691e-08, 'lambda_l2': 1.2384798722380232e-06, 'num_leaves': 213, 'feature_fraction': 0.7117381458600236, 'bagging_fraction': 0.5909716352672788, 'bagging_freq': 3, 'min_child_samples': 38, 'learning_rate': 0.09493558032042398, 'max_depth': 17, 'min_data_in_leaf': 332, 'max_bin': 947, 'subsample': 0.6080680734975056, 'colsample_bytree': 0.9711248598729108, 'subsample_freq': 6, 'min_split_gain': 0.873735164851111}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:49:08,963] Trial 2 finished with value: 80000.0 and parameters: {'lambda_l1': 8.181371110088756, 'lambda_l2': 7.871225751886661, 'num_leaves': 217, 'feature_fraction': 0.70259157080051, 'bagging_fraction': 0.05174033431195067, 'bagging_freq': 1, 'min_child_samples': 34, 'learning_rate': 0.0016186991118308416, 'max_depth': 17, 'min_data_in_leaf': 126, 'max_bin': 701, 'subsample': 0.6473735308110042, 'colsample_bytree': 0.7781968519573427, 'subsample_freq': 9, 'min_split_gain': 0.8340688296585846}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:49:17,244] Trial 3 finished with value: 80000.0 and parameters: {'lambda_l1': 0.0002433318412770904, 'lambda_l2': 0.20913138242030008, 'num_leaves': 194, 'feature_fraction': 0.750942975843429, 'bagging_fraction': 0.8472654221508287, 'bagging_freq': 5, 'min_child_samples': 31, 'learning_rate': 0.0025194219814712233, 'max_depth': 6, 'min_data_in_leaf': 759, 'max_bin': 758, 'subsample': 0.9479768563363863, 'colsample_bytree': 0.5365954107535303, 'subsample_freq': 5, 'min_split_gain': 0.857065525555434}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:49:25,373] Trial 4 finished with value: 80000.0 and parameters: {'lambda_l1': 2.9711335692471894, 'lambda_l2': 6.273148332339426e-06, 'num_leaves': 240, 'feature_fraction': 0.09888720643338444, 'bagging_fraction': 0.47601412763534184, 'bagging_freq': 10, 'min_child_samples': 29, 'learning_rate': 0.0008175886990978593, 'max_depth': 3, 'min_data_in_leaf': 278, 'max_bin': 292, 'subsample': 0.8376091576884557, 'colsample_bytree': 0.8216568065106391, 'subsample_freq': 5, 'min_split_gain': 0.041100224213395764}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:49:33,764] Trial 5 finished with value: 80000.0 and parameters: {'lambda_l1': 4.057493361726003, 'lambda_l2': 0.22031708975080816, 'num_leaves': 76, 'feature_fraction': 0.2300178312250018, 'bagging_fraction': 0.5855234378612674, 'bagging_freq': 6, 'min_child_samples': 79, 'learning_rate': 0.0003034065848221593, 'max_depth': 14, 'min_data_in_leaf': 41, 'max_bin': 233, 'subsample': 0.8808239937303438, 'colsample_bytree': 0.9476041536934696, 'subsample_freq': 1, 'min_split_gain': 0.8297558587182479}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:49:42,064] Trial 6 finished with value: 80000.0 and parameters: {'lambda_l1': 2.109163088746978, 'lambda_l2': 0.00861137201774114, 'num_leaves': 105, 'feature_fraction': 0.7247845227868048, 'bagging_fraction': 0.62458988476378, 'bagging_freq': 3, 'min_child_samples': 95, 'learning_rate': 0.001435939148435811, 'max_depth': 19, 'min_data_in_leaf': 939, 'max_bin': 925, 'subsample': 0.9717098890546924, 'colsample_bytree': 0.608858947979104, 'subsample_freq': 10, 'min_split_gain': 0.0279543811881815}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:49:50,342] Trial 7 finished with value: 80000.0 and parameters: {'lambda_l1': 1.6831116039368825e-08, 'lambda_l2': 0.737902140110237, 'num_leaves': 26, 'feature_fraction': 0.22116173793213073, 'bagging_fraction': 0.5976850651053692, 'bagging_freq': 4, 'min_child_samples': 51, 'learning_rate': 0.000997156451853979, 'max_depth': 17, 'min_data_in_leaf': 740, 'max_bin': 625, 'subsample': 0.5993975606902542, 'colsample_bytree': 0.5205691311907955, 'subsample_freq': 2, 'min_split_gain': 0.8346904650234953}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:49:58,609] Trial 8 finished with value: 80000.0 and parameters: {'lambda_l1': 0.0017265568610151882, 'lambda_l2': 0.31302204033463454, 'num_leaves': 85, 'feature_fraction': 0.9691566588796873, 'bagging_fraction': 0.08876672018587844, 'bagging_freq': 2, 'min_child_samples': 89, 'learning_rate': 0.00396021902550068, 'max_depth': 5, 'min_data_in_leaf': 238, 'max_bin': 870, 'subsample': 0.5972349305506004, 'colsample_bytree': 0.7034804570474329, 'subsample_freq': 10, 'min_split_gain': 0.799891708736094}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:50:07,109] Trial 9 finished with value: 80000.0 and parameters: {'lambda_l1': 0.07278760009693734, 'lambda_l2': 1.613946693195108e-06, 'num_leaves': 23, 'feature_fraction': 0.43861545384367784, 'bagging_fraction': 0.5564524856187766, 'bagging_freq': 2, 'min_child_samples': 59, 'learning_rate': 0.0007148465761211951, 'max_depth': 11, 'min_data_in_leaf': 512, 'max_bin': 190, 'subsample': 0.7515968091020109, 'colsample_bytree': 0.640140955924632, 'subsample_freq': 10, 'min_split_gain': 0.20172086110234733}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:50:17,865] Trial 10 finished with value: 33403.0 and parameters: {'lambda_l1': 2.2770164290718938e-06, 'lambda_l2': 2.8141426065965305e-08, 'num_leaves': 165, 'feature_fraction': 0.4907236248428172, 'bagging_fraction': 0.9494846143119563, 'bagging_freq': 7, 'min_child_samples': 7, 'learning_rate': 0.07518341868709635, 'max_depth': 10, 'min_data_in_leaf': 438, 'max_bin': 483, 'subsample': 0.5589126921482106, 'colsample_bytree': 0.9912623379856087, 'subsample_freq': 7, 'min_split_gain': 0.4792565993102834}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:50:27,717] Trial 11 finished with value: 31786.0 and parameters: {'lambda_l1': 1.9086761478188183e-06, 'lambda_l2': 3.33441193822078e-08, 'num_leaves': 163, 'feature_fraction': 0.4699425801067088, 'bagging_fraction': 0.9568461037191565, 'bagging_freq': 7, 'min_child_samples': 7, 'learning_rate': 0.09889911980119258, 'max_depth': 10, 'min_data_in_leaf': 420, 'max_bin': 465, 'subsample': 0.5157591087708624, 'colsample_bytree': 0.9924911549343693, 'subsample_freq': 7, 'min_split_gain': 0.5097694639063617}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:50:36,658] Trial 12 finished with value: 31505.0 and parameters: {'lambda_l1': 1.5170748043757156e-08, 'lambda_l2': 1.119151776402818e-08, 'num_leaves': 153, 'feature_fraction': 0.5834211247038956, 'bagging_fraction': 0.7880170769566214, 'bagging_freq': 8, 'min_child_samples': 9, 'learning_rate': 0.08909300946131733, 'max_depth': 14, 'min_data_in_leaf': 464, 'max_bin': 427, 'subsample': 0.5004713340007518, 'colsample_bytree': 0.8930984439252456, 'subsample_freq': 7, 'min_split_gain': 0.5359728506539525}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:50:45,027] Trial 13 finished with value: 47508.0 and parameters: {'lambda_l1': 3.312796560327163e-08, 'lambda_l2': 2.3355373523486425e-06, 'num_leaves': 166, 'feature_fraction': 0.942364464201817, 'bagging_fraction': 0.7624708046046678, 'bagging_freq': 9, 'min_child_samples': 20, 'learning_rate': 0.020965918458290756, 'max_depth': 14, 'min_data_in_leaf': 587, 'max_bin': 400, 'subsample': 0.5088019708879186, 'colsample_bytree': 0.8841192571276016, 'subsample_freq': 3, 'min_split_gain': 0.5626509949364403}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:50:53,268] Trial 14 finished with value: 46439.0 and parameters: {'lambda_l1': 6.292070065424258e-05, 'lambda_l2': 8.482830386561077e-05, 'num_leaves': 127, 'feature_fraction': 0.6112380076147959, 'bagging_fraction': 0.323246978025749, 'bagging_freq': 8, 'min_child_samples': 42, 'learning_rate': 0.02357488159735422, 'max_depth': 14, 'min_data_in_leaf': 303, 'max_bin': 604, 'subsample': 0.7140347599999867, 'colsample_bytree': 0.8762784033875994, 'subsample_freq': 8, 'min_split_gain': 0.9939025715767894}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:51:01,847] Trial 15 finished with value: 47397.0 and parameters: {'lambda_l1': 1.1914062117556227e-07, 'lambda_l2': 1.0195793517103e-08, 'num_leaves': 251, 'feature_fraction': 0.34637787991491664, 'bagging_fraction': 0.7605465895793085, 'bagging_freq': 5, 'min_child_samples': 16, 'learning_rate': 0.02755162844707103, 'max_depth': 16, 'min_data_in_leaf': 641, 'max_bin': 366, 'subsample': 0.63965549199624, 'colsample_bytree': 0.8971464685086245, 'subsample_freq': 4, 'min_split_gain': 0.3105973138834842}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:51:10,340] Trial 16 finished with value: 69752.0 and parameters: {'lambda_l1': 1.6063780174224153e-05, 'lambda_l2': 2.874484550540303e-07, 'num_leaves': 141, 'feature_fraction': 0.8423321330049246, 'bagging_fraction': 0.7325860946836149, 'bagging_freq': 4, 'min_child_samples': 65, 'learning_rate': 0.008395533701022282, 'max_depth': 13, 'min_data_in_leaf': 375, 'max_bin': 998, 'subsample': 0.5546234958285712, 'colsample_bytree': 0.828663666435214, 'subsample_freq': 7, 'min_split_gain': 0.6259139539545997}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:51:18,722] Trial 17 finished with value: 41947.0 and parameters: {'lambda_l1': 2.572064626768767e-07, 'lambda_l2': 4.249055655763194e-05, 'num_leaves': 191, 'feature_fraction': 0.6083646636831108, 'bagging_fraction': 0.33370656835661827, 'bagging_freq': 10, 'min_child_samples': 45, 'learning_rate': 0.04309859515893852, 'max_depth': 8, 'min_data_in_leaf': 544, 'max_bin': 110, 'subsample': 0.780999966447751, 'colsample_bytree': 0.9329275312558843, 'subsample_freq': 6, 'min_split_gain': 0.34640049395204003}. Best is trial 1 with value: 30076.0.
# [I 2024-07-12 17:51:27,019] Trial 18 finished with value: 78480.0 and parameters: {'lambda_l1': 0.004213680748202665, 'lambda_l2': 0.001501824436428998, 'num_leaves': 135, 'feature_fraction': 0.5966157298674845, 'bagging_fraction': 0.6751963444286354, 'bagging_freq': 8, 'min_child_samples': 71, 'learning_rate': 0.009279154109242958, 'max_depth': 18, 'min_data_in_leaf': 687, 'max_bin': 794, 'subsample': 0.66236685806182, 'colsample_bytree': 0.7409995059239831, 'subsample_freq': 8, 'min_split_gain': 0.977139001505131}. Best is trial 1 with value: 30076.0.
# Sem novas melhorias a partir da iteração 19
# Melhor score: 30076.0

# %%
# Salvando as melhores configurações
with open('./artefatos/LGBM/LGBM_best_config.pkl', 'wb') as f:
    pickle.dump(best, f)

# %% [markdown]
# > XGBoost

# %%
import optuna
from sklearn.model_selection import StratifiedKFold

EARLY_STOPPING = 15

class EarlyStoppingExceeded(optuna.exceptions.OptunaError):
    early_stop = EARLY_STOPPING
    early_stop_count = 0
    best_score = None

def early_stopping_opt(study, trial):
    if EarlyStoppingExceeded.best_score == None:
      EarlyStoppingExceeded.best_score = study.best_value

    if study.best_value < EarlyStoppingExceeded.best_score:
        EarlyStoppingExceeded.best_score = study.best_value
        EarlyStoppingExceeded.early_stop_count = 0
    else:
      if EarlyStoppingExceeded.early_stop_count > EarlyStoppingExceeded.early_stop:
            EarlyStoppingExceeded.early_stop_count = 0
            best_score = None
            raise EarlyStoppingExceeded()
      else:
            EarlyStoppingExceeded.early_stop_count=EarlyStoppingExceeded.early_stop_count+1
    return

def objective(trial):
    # Var. de controle da métrica
    avg_loss_func = 0

    # Criando os parametros a serem testados
    params = {
        "objective": "binary:logistic",
        "eval_metric": "auc",
        "verbosity": 0,
        "booster": "gbtree",
        "lambda": trial.suggest_float("lambda", 1e-8, 10.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 10.0, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 20),
        "eta": trial.suggest_float("eta", 1e-4, 1e-1, log=True),
        "gamma": trial.suggest_float("gamma", 1e-8, 10.0, log=True),
        "grow_policy": trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"]),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 100),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.5, 1.0),
        "colsample_bynode": trial.suggest_float("colsample_bynode", 0.5, 1.0),
        "max_bin": trial.suggest_int("max_bin", 100, 1000),
        "scale_pos_weight": trial.suggest_float("scale_pos_weight", 1e-2, 10.0, log=True),
    }

    # Fazendo os Splits (Cross Validation)
    cv = StratifiedKFold(n_splits= 5, random_state= 1, shuffle= True)

    for train_idx, validation_idx in cv.split(X_train, y_train):
        # Instancia o Modelo
        model = XGBClassifier(**params, random_state= 1, n_jobs = -1)

        # Vars Preditoras - Treino
        X_train_cv = X_train.iloc[train_idx]

        # Vars Preditoras - Validação
        X_validation_cv = X_train.iloc[validation_idx]

        # Target - Treino
        y_train_cv = y_train.iloc[train_idx]

        # Target - Validação
        y_validation_cv = y_train.iloc[validation_idx]

        # Aplicando o DATAPREP nos conjuntos de Treino
        X_train_cv_processed = pd.DataFrame(
            data = dp_boost_pipeline.fit_transform(X_train_cv, y_train_cv),
            columns = dp_boost_vars # Lista de variáveis que saem do pipeline na etapa de dataprep
        )[selected_features] # Filtrando apenas as features da etapa de feature selection

        # Aplicando o DATAPREP nos conjuntos de Validação
        X_validation_cv_processed = pd.DataFrame(
            data = dp_boost_pipeline.transform(X_validation_cv),
            columns= dp_boost_vars
        )[selected_features]

        # Treinando o Modelo
        model.fit(X_train_cv_processed, y_train_cv)

        # Fazendo as predições
        y_pred = model.predict(X_validation_cv_processed)

        avg_loss_func += functions.loss_function(y_validation_cv, y_pred)
    
    return avg_loss_func/5

study = optuna.create_study(
    direction= 'minimize',
    study_name= 'XGBClassifier_v01',
    storage= 'sqlite:///XGBClassifier_v01.db'
)

try:
    study.optimize(objective, timeout=7200, callbacks= [early_stopping_opt])

except EarlyStoppingExceeded:
    print(f'Sem novas melhorias a partir da iteração {len(study.trials)}')

best = study.best_trial

print(f'Melhor score: {best.value}')
# Out:
# [I 2024-07-12 17:51:27,198] A new study created in RDB with name: XGBClassifier_v01
# [I 2024-07-12 17:51:39,335] Trial 0 finished with value: 37412.0 and parameters: {'lambda': 0.0001495878742845022, 'alpha': 0.0027471681135135795, 'max_depth': 9, 'eta': 0.002303821512846776, 'gamma': 2.6851714638660824e-05, 'grow_policy': 'depthwise', 'min_child_weight': 39, 'subsample': 0.6935490448293671, 'colsample_bytree': 0.6753908691774138, 'colsample_bylevel': 0.5534726181406316, 'colsample_bynode': 0.8287326933404688, 'max_bin': 170, 'scale_pos_weight': 2.1147858206033257}. Best is trial 0 with value: 37412.0.
# [I 2024-07-12 17:51:49,325] Trial 1 finished with value: 80000.0 and parameters: {'lambda': 0.0016042506856853928, 'alpha': 0.0026554853428155333, 'max_depth': 13, 'eta': 0.03358625939447244, 'gamma': 1.1545485666860259e-08, 'grow_policy': 'lossguide', 'min_child_weight': 96, 'subsample': 0.759191671031869, 'colsample_bytree': 0.6337217144887333, 'colsample_bylevel': 0.6641768689866292, 'colsample_bynode': 0.9406875010161933, 'max_bin': 513, 'scale_pos_weight': 0.03110757833890215}. Best is trial 0 with value: 37412.0.
# [I 2024-07-12 17:52:01,887] Trial 2 finished with value: 42812.0 and parameters: {'lambda': 0.5131767539253184, 'alpha': 4.1139928974975044e-08, 'max_depth': 16, 'eta': 0.027090631987040235, 'gamma': 0.0065702726025613075, 'grow_policy': 'lossguide', 'min_child_weight': 37, 'subsample': 0.6450007323230388, 'colsample_bytree': 0.983638387160372, 'colsample_bylevel': 0.964681374611148, 'colsample_bynode': 0.8560773455184436, 'max_bin': 375, 'scale_pos_weight': 0.9738497962455804}. Best is trial 0 with value: 37412.0.
# [I 2024-07-12 17:52:12,713] Trial 3 finished with value: 80000.0 and parameters: {'lambda': 0.002551315565348159, 'alpha': 0.012625994062827621, 'max_depth': 7, 'eta': 0.00015856336927700922, 'gamma': 6.88025519526846, 'grow_policy': 'depthwise', 'min_child_weight': 18, 'subsample': 0.6690536280652353, 'colsample_bytree': 0.6005536187871781, 'colsample_bylevel': 0.9342668142615014, 'colsample_bynode': 0.559338678134245, 'max_bin': 753, 'scale_pos_weight': 0.07224763337728426}. Best is trial 0 with value: 37412.0.
# [I 2024-07-12 17:52:22,175] Trial 4 finished with value: 80000.0 and parameters: {'lambda': 1.318227743467385e-08, 'alpha': 2.639915835318737, 'max_depth': 13, 'eta': 0.00010236219970894404, 'gamma': 0.035720684928825665, 'grow_policy': 'lossguide', 'min_child_weight': 39, 'subsample': 0.9620488563325658, 'colsample_bytree': 0.7560756950362896, 'colsample_bylevel': 0.920045741302089, 'colsample_bynode': 0.8910854604938494, 'max_bin': 257, 'scale_pos_weight': 0.03421016134588321}. Best is trial 0 with value: 37412.0.
# [I 2024-07-12 17:52:34,234] Trial 5 finished with value: 80000.0 and parameters: {'lambda': 0.0003259450564432328, 'alpha': 5.25638008836441e-06, 'max_depth': 10, 'eta': 0.03674322396326684, 'gamma': 2.1482474374998276e-07, 'grow_policy': 'lossguide', 'min_child_weight': 23, 'subsample': 0.9484841206346941, 'colsample_bytree': 0.8723705379365381, 'colsample_bylevel': 0.6349555671884008, 'colsample_bynode': 0.5582294658211684, 'max_bin': 467, 'scale_pos_weight': 0.16893051611930773}. Best is trial 0 with value: 37412.0.
# [I 2024-07-12 17:52:44,547] Trial 6 finished with value: 80000.0 and parameters: {'lambda': 0.01696787664002985, 'alpha': 2.3488880466169556e-07, 'max_depth': 20, 'eta': 0.07464044841483698, 'gamma': 8.817022660809434, 'grow_policy': 'depthwise', 'min_child_weight': 98, 'subsample': 0.9641768482090682, 'colsample_bytree': 0.8948226304630311, 'colsample_bylevel': 0.8361898910790301, 'colsample_bynode': 0.961894484059427, 'max_bin': 141, 'scale_pos_weight': 0.39794522880125255}. Best is trial 0 with value: 37412.0.
# [I 2024-07-12 17:52:58,362] Trial 7 finished with value: 20331.0 and parameters: {'lambda': 5.7029677018495244e-08, 'alpha': 0.0009248820715253561, 'max_depth': 15, 'eta': 0.0001261528424159129, 'gamma': 0.00020419203407148368, 'grow_policy': 'lossguide', 'min_child_weight': 86, 'subsample': 0.6063841860478514, 'colsample_bytree': 0.9275149222021375, 'colsample_bylevel': 0.7859982779665933, 'colsample_bynode': 0.7462459098876696, 'max_bin': 251, 'scale_pos_weight': 4.658342225010419}. Best is trial 7 with value: 20331.0.
# [I 2024-07-12 17:53:10,370] Trial 8 finished with value: 29908.0 and parameters: {'lambda': 0.0007909805417576616, 'alpha': 0.05424236254587985, 'max_depth': 10, 'eta': 0.009005741616300501, 'gamma': 0.3281458297472559, 'grow_policy': 'depthwise', 'min_child_weight': 82, 'subsample': 0.5251180823826664, 'colsample_bytree': 0.9679997839262862, 'colsample_bylevel': 0.7458800539011925, 'colsample_bynode': 0.7377685301275423, 'max_bin': 388, 'scale_pos_weight': 2.4560882913929647}. Best is trial 7 with value: 20331.0.
# [I 2024-07-12 17:53:23,814] Trial 9 finished with value: 80000.0 and parameters: {'lambda': 9.878167788630937e-08, 'alpha': 0.0007501605620592005, 'max_depth': 13, 'eta': 0.00021740087751750053, 'gamma': 0.01726160871963404, 'grow_policy': 'lossguide', 'min_child_weight': 25, 'subsample': 0.9202675169752759, 'colsample_bytree': 0.9766864249827873, 'colsample_bylevel': 0.9812680842001151, 'colsample_bynode': 0.9477918803464309, 'max_bin': 946, 'scale_pos_weight': 0.0727793912837253}. Best is trial 7 with value: 20331.0.
# [I 2024-07-12 17:53:33,850] Trial 10 finished with value: 24499.0 and parameters: {'lambda': 1.5869358017496796e-06, 'alpha': 1.326150338077677e-05, 'max_depth': 3, 'eta': 0.000815177293443552, 'gamma': 6.401377480456865e-05, 'grow_policy': 'lossguide', 'min_child_weight': 65, 'subsample': 0.5051623656883135, 'colsample_bytree': 0.5040661093105356, 'colsample_bylevel': 0.8024802799326073, 'colsample_bynode': 0.6976959799579026, 'max_bin': 670, 'scale_pos_weight': 6.791069817189069}. Best is trial 7 with value: 20331.0.
# [I 2024-07-12 17:53:43,993] Trial 11 finished with value: 21566.0 and parameters: {'lambda': 1.5823856595433747e-06, 'alpha': 1.6463542784520643e-05, 'max_depth': 3, 'eta': 0.0007459140292741947, 'gamma': 0.00011156082523836746, 'grow_policy': 'lossguide', 'min_child_weight': 67, 'subsample': 0.5001914271121313, 'colsample_bytree': 0.762793644111607, 'colsample_bylevel': 0.796460431281943, 'colsample_bynode': 0.6837979971497299, 'max_bin': 663, 'scale_pos_weight': 6.200847142688446}. Best is trial 7 with value: 20331.0.
# [I 2024-07-12 17:53:54,480] Trial 12 finished with value: 20075.0 and parameters: {'lambda': 4.010182267546105e-06, 'alpha': 2.1206047624492782e-05, 'max_depth': 3, 'eta': 0.0006270089413142462, 'gamma': 3.4224821837284976e-06, 'grow_policy': 'lossguide', 'min_child_weight': 66, 'subsample': 0.584482553424293, 'colsample_bytree': 0.7895952770700174, 'colsample_bylevel': 0.7533876042957849, 'colsample_bynode': 0.6574778993512556, 'max_bin': 679, 'scale_pos_weight': 7.505796460333565}. Best is trial 12 with value: 20075.0.
# [I 2024-07-12 17:54:08,603] Trial 13 finished with value: 42392.0 and parameters: {'lambda': 5.318110177733618e-06, 'alpha': 0.00014078453682027055, 'max_depth': 17, 'eta': 0.0005391827280160367, 'gamma': 1.8244249113716976e-06, 'grow_policy': 'lossguide', 'min_child_weight': 65, 'subsample': 0.6080824129928911, 'colsample_bytree': 0.8419061153898831, 'colsample_bylevel': 0.7069996445951688, 'colsample_bynode': 0.6542901753855885, 'max_bin': 924, 'scale_pos_weight': 1.9351088245440633}. Best is trial 12 with value: 20075.0.
# [I 2024-07-12 17:54:20,464] Trial 14 finished with value: 17082.0 and parameters: {'lambda': 1.1312030589647922e-05, 'alpha': 0.6049753200092014, 'max_depth': 6, 'eta': 0.002463594092971127, 'gamma': 2.1011134437312713e-06, 'grow_policy': 'lossguide', 'min_child_weight': 80, 'subsample': 0.8005319563031872, 'colsample_bytree': 0.8239749763680332, 'colsample_bylevel': 0.8847572328842985, 'colsample_bynode': 0.7931514258531653, 'max_bin': 794, 'scale_pos_weight': 8.570893902330544}. Best is trial 14 with value: 17082.0.
# [I 2024-07-12 17:54:30,483] Trial 15 finished with value: 71939.0 and parameters: {'lambda': 1.4815114996769483e-05, 'alpha': 8.65872794364956, 'max_depth': 6, 'eta': 0.0031941601823168, 'gamma': 2.2855943018359366e-06, 'grow_policy': 'lossguide', 'min_child_weight': 54, 'subsample': 0.8199678567091309, 'colsample_bytree': 0.8030500353022371, 'colsample_bylevel': 0.8793817956047102, 'colsample_bynode': 0.6216470476563231, 'max_bin': 812, 'scale_pos_weight': 0.6694566536243882}. Best is trial 14 with value: 17082.0.
# [I 2024-07-12 17:54:41,794] Trial 16 finished with value: 16978.0 and parameters: {'lambda': 2.840724160386154e-05, 'alpha': 0.18797896191631935, 'max_depth': 6, 'eta': 0.002385672468325358, 'gamma': 7.710121118794394e-08, 'grow_policy': 'lossguide', 'min_child_weight': 77, 'subsample': 0.8492860335402845, 'colsample_bytree': 0.6894713162566213, 'colsample_bylevel': 0.860946126994462, 'colsample_bynode': 0.8020045252773518, 'max_bin': 638, 'scale_pos_weight': 7.920720222718712}. Best is trial 16 with value: 16978.0.
# [I 2024-07-12 17:54:53,055] Trial 17 finished with value: 16394.0 and parameters: {'lambda': 9.40442422668009, 'alpha': 0.4037322542556311, 'max_depth': 7, 'eta': 0.004352197582477402, 'gamma': 1.1076207986873944e-08, 'grow_policy': 'lossguide', 'min_child_weight': 79, 'subsample': 0.8533553390709768, 'colsample_bytree': 0.7038834799614127, 'colsample_bylevel': 0.8727385274965864, 'colsample_bynode': 0.8060783332312654, 'max_bin': 836, 'scale_pos_weight': 9.451520187830408}. Best is trial 17 with value: 16394.0.
# [I 2024-07-12 17:55:02,589] Trial 18 finished with value: 80000.0 and parameters: {'lambda': 7.970303758536963, 'alpha': 0.13532326387490948, 'max_depth': 8, 'eta': 0.006244092290451889, 'gamma': 1.3695065523145353e-08, 'grow_policy': 'depthwise', 'min_child_weight': 52, 'subsample': 0.8816060946053066, 'colsample_bytree': 0.693839250938976, 'colsample_bylevel': 0.8639510144353062, 'colsample_bynode': 0.7958352109791412, 'max_bin': 993, 'scale_pos_weight': 0.010985540041512786}. Best is trial 17 with value: 16394.0.
# [I 2024-07-12 17:55:12,988] Trial 19 finished with value: 31062.0 and parameters: {'lambda': 0.06424954727820886, 'alpha': 0.47759647876610006, 'max_depth': 5, 'eta': 0.01059282283763369, 'gamma': 1.0479533193735922e-07, 'grow_policy': 'lossguide', 'min_child_weight': 80, 'subsample': 0.8567056582819965, 'colsample_bytree': 0.544569718708606, 'colsample_bylevel': 0.5109615211313046, 'colsample_bynode': 0.8916098994826944, 'max_bin': 580, 'scale_pos_weight': 3.1344252230988374}. Best is trial 17 with value: 16394.0.
# [I 2024-07-12 17:55:23,363] Trial 20 finished with value: 80000.0 and parameters: {'lambda': 6.5745109485989275, 'alpha': 0.024181244205057833, 'max_depth': 5, 'eta': 0.004464051411099983, 'gamma': 1.3722723763953664e-07, 'grow_policy': 'lossguide', 'min_child_weight': 91, 'subsample': 0.7292531983571138, 'colsample_bytree': 0.7127015395584688, 'colsample_bylevel': 0.9980802968932054, 'colsample_bynode': 0.7987855570487281, 'max_bin': 862, 'scale_pos_weight': 0.8357908642264112}. Best is trial 17 with value: 16394.0.
# [I 2024-07-12 17:55:34,999] Trial 21 finished with value: 15846.0 and parameters: {'lambda': 8.609455274106632e-05, 'alpha': 0.7803924475636612, 'max_depth': 7, 'eta': 0.0018433017532243814, 'gamma': 3.593542811456432e-07, 'grow_policy': 'lossguide', 'min_child_weight': 76, 'subsample': 0.8161834179751698, 'colsample_bytree': 0.6269002684374425, 'colsample_bylevel': 0.8912017290059908, 'colsample_bynode': 0.7788936739441128, 'max_bin': 788, 'scale_pos_weight': 9.970228981789885}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:55:46,973] Trial 22 finished with value: 16101.0 and parameters: {'lambda': 8.177019860009034e-05, 'alpha': 0.7946359410174921, 'max_depth': 8, 'eta': 0.0014102615881759484, 'gamma': 5.9260719870792324e-08, 'grow_policy': 'lossguide', 'min_child_weight': 74, 'subsample': 0.878474271937395, 'colsample_bytree': 0.6416869862963489, 'colsample_bylevel': 0.9105234813720052, 'colsample_bynode': 0.758395311733578, 'max_bin': 743, 'scale_pos_weight': 9.623713773841507}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:55:58,248] Trial 23 finished with value: 27327.0 and parameters: {'lambda': 9.749271496444413e-05, 'alpha': 2.1964045509572157, 'max_depth': 8, 'eta': 0.0014332803417930545, 'gamma': 3.999588793922613e-07, 'grow_policy': 'lossguide', 'min_child_weight': 71, 'subsample': 0.8973222673349904, 'colsample_bytree': 0.6092722246148212, 'colsample_bylevel': 0.9214269541184268, 'colsample_bynode': 0.7319607147702013, 'max_bin': 744, 'scale_pos_weight': 3.757107234100061}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:56:08,859] Trial 24 finished with value: 50477.0 and parameters: {'lambda': 0.031711119733619016, 'alpha': 7.74599931471431, 'max_depth': 11, 'eta': 0.0012909462592787045, 'gamma': 3.135511644509272e-08, 'grow_policy': 'lossguide', 'min_child_weight': 58, 'subsample': 0.7858873755549208, 'colsample_bytree': 0.6349241313173135, 'colsample_bylevel': 0.937876840732179, 'colsample_bynode': 0.8678797891222488, 'max_bin': 853, 'scale_pos_weight': 1.4400451256310285}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:56:20,108] Trial 25 finished with value: 28479.0 and parameters: {'lambda': 0.004792046124675438, 'alpha': 1.2618540856803493, 'max_depth': 8, 'eta': 0.0003507513229849835, 'gamma': 8.71217795556411e-06, 'grow_policy': 'lossguide', 'min_child_weight': 74, 'subsample': 0.8273414690637744, 'colsample_bytree': 0.5804150886559822, 'colsample_bylevel': 0.8328731007561934, 'colsample_bynode': 0.7685281879862772, 'max_bin': 879, 'scale_pos_weight': 3.881906508772765}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:56:34,693] Trial 26 finished with value: 23302.0 and parameters: {'lambda': 0.24157496061381314, 'alpha': 0.011116699877238654, 'max_depth': 11, 'eta': 0.001305150677570569, 'gamma': 0.0009590880888616786, 'grow_policy': 'depthwise', 'min_child_weight': 3, 'subsample': 0.7511027904967433, 'colsample_bytree': 0.6566500031496401, 'colsample_bylevel': 0.8942406215823756, 'colsample_bynode': 0.9979784650650831, 'max_bin': 728, 'scale_pos_weight': 4.993464508320139}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:56:45,039] Trial 27 finished with value: 16359.0 and parameters: {'lambda': 5.024364252216024e-05, 'alpha': 0.209936847522314, 'max_depth': 5, 'eta': 0.012067487311487176, 'gamma': 5.762181151520971e-07, 'grow_policy': 'lossguide', 'min_child_weight': 90, 'subsample': 0.9109849839773655, 'colsample_bytree': 0.5666328877956242, 'colsample_bylevel': 0.9554958533597013, 'colsample_bynode': 0.5007557519070361, 'max_bin': 572, 'scale_pos_weight': 8.8967584691683}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:56:55,095] Trial 28 finished with value: 54870.0 and parameters: {'lambda': 6.178980739500644e-05, 'alpha': 0.06658347398442542, 'max_depth': 4, 'eta': 0.014302967509133563, 'gamma': 6.216469903463322e-07, 'grow_policy': 'lossguide', 'min_child_weight': 90, 'subsample': 0.9193494027103037, 'colsample_bytree': 0.5459416009473743, 'colsample_bylevel': 0.9577126385258663, 'colsample_bynode': 0.5252010182031931, 'max_bin': 566, 'scale_pos_weight': 1.3592265534657395}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:57:06,181] Trial 29 finished with value: 71836.0 and parameters: {'lambda': 0.0003667508616780769, 'alpha': 0.003475683551500002, 'max_depth': 9, 'eta': 0.020023293479629285, 'gamma': 1.7986919344873582e-05, 'grow_policy': 'depthwise', 'min_child_weight': 42, 'subsample': 0.9834798845339069, 'colsample_bytree': 0.5011560739786315, 'colsample_bylevel': 0.6101404499588956, 'colsample_bynode': 0.5895587369915937, 'max_bin': 613, 'scale_pos_weight': 0.44553623528019526}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:57:16,700] Trial 30 finished with value: 39745.0 and parameters: {'lambda': 9.579005706408477e-07, 'alpha': 2.67729024083829, 'max_depth': 5, 'eta': 0.006789085244868938, 'gamma': 6.020576458855624e-07, 'grow_policy': 'lossguide', 'min_child_weight': 99, 'subsample': 0.7150455745129917, 'colsample_bytree': 0.5612141372274911, 'colsample_bylevel': 0.9102956763904496, 'colsample_bynode': 0.6983888421106568, 'max_bin': 478, 'scale_pos_weight': 2.428424293050058}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:57:28,385] Trial 31 finished with value: 16151.0 and parameters: {'lambda': 7.933984696466783e-05, 'alpha': 0.32107794036764553, 'max_depth': 7, 'eta': 0.0038611639773527538, 'gamma': 2.3653827190939675e-08, 'grow_policy': 'lossguide', 'min_child_weight': 90, 'subsample': 0.8707944133074781, 'colsample_bytree': 0.7226699931396928, 'colsample_bylevel': 0.8381194344293245, 'colsample_bynode': 0.833867700058585, 'max_bin': 788, 'scale_pos_weight': 9.854536819024329}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:57:40,742] Trial 32 finished with value: 16362.0 and parameters: {'lambda': 0.00015813737741507666, 'alpha': 0.20576653025257444, 'max_depth': 9, 'eta': 0.001684072317657751, 'gamma': 3.83222314379857e-08, 'grow_policy': 'lossguide', 'min_child_weight': 90, 'subsample': 0.8978612367651266, 'colsample_bytree': 0.6511136476746017, 'colsample_bylevel': 0.8336304986474137, 'colsample_bynode': 0.8434142024958489, 'max_bin': 719, 'scale_pos_weight': 9.467634021919519}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:57:52,636] Trial 33 finished with value: 22468.0 and parameters: {'lambda': 8.745554196676205e-05, 'alpha': 0.041016513436491556, 'max_depth': 7, 'eta': 0.0038720943733827765, 'gamma': 3.8958092735531595e-08, 'grow_policy': 'lossguide', 'min_child_weight': 86, 'subsample': 0.7797317674137447, 'colsample_bytree': 0.7234059877725498, 'colsample_bylevel': 0.9661914692682763, 'colsample_bynode': 0.8314199117674689, 'max_bin': 787, 'scale_pos_weight': 4.6966694810638625}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:58:03,058] Trial 34 finished with value: 80000.0 and parameters: {'lambda': 0.0016370714487288663, 'alpha': 0.0039130835142516095, 'max_depth': 4, 'eta': 0.006213607091190258, 'gamma': 5.634113523313094e-07, 'grow_policy': 'lossguide', 'min_child_weight': 94, 'subsample': 0.9282085239277982, 'colsample_bytree': 0.5962181540329851, 'colsample_bylevel': 0.9358054938443373, 'colsample_bynode': 0.9014796364380689, 'max_bin': 495, 'scale_pos_weight': 0.19079199257957674}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:58:13,896] Trial 35 finished with value: 29617.0 and parameters: {'lambda': 4.074229071019084e-05, 'alpha': 1.0990291855325292, 'max_depth': 7, 'eta': 0.0019279040092870623, 'gamma': 8.869201349844113e-06, 'grow_policy': 'lossguide', 'min_child_weight': 60, 'subsample': 0.8750674003787016, 'colsample_bytree': 0.664285302457644, 'colsample_bylevel': 0.9962517266446362, 'colsample_bynode': 0.5091220225305253, 'max_bin': 411, 'scale_pos_weight': 3.104072297909888}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:58:26,259] Trial 36 finished with value: 20559.0 and parameters: {'lambda': 0.006394823965560081, 'alpha': 0.014366184266753153, 'max_depth': 10, 'eta': 0.0010081386414942726, 'gamma': 0.0015154729037924256, 'grow_policy': 'lossguide', 'min_child_weight': 72, 'subsample': 0.8146917722316677, 'colsample_bytree': 0.6208030095007742, 'colsample_bylevel': 0.9045148676141068, 'colsample_bynode': 0.7173272095777343, 'max_bin': 902, 'scale_pos_weight': 5.926588638717468}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:58:36,428] Trial 37 finished with value: 34664.0 and parameters: {'lambda': 0.0005520954250596972, 'alpha': 9.522253475300364, 'max_depth': 8, 'eta': 0.054663466892759416, 'gamma': 2.991740518178243e-07, 'grow_policy': 'depthwise', 'min_child_weight': 86, 'subsample': 0.9968446667752844, 'colsample_bytree': 0.7364610027387295, 'colsample_bylevel': 0.9547609066395732, 'colsample_bynode': 0.7703400902964699, 'max_bin': 548, 'scale_pos_weight': 1.4612437118623947}. Best is trial 21 with value: 15846.0.
# [I 2024-07-12 17:58:48,852] Trial 38 finished with value: 15677.0 and parameters: {'lambda': 0.00019059707002131644, 'alpha': 0.11985014979539639, 'max_depth': 12, 'eta': 0.019097792517816434, 'gamma': 6.819510205178374e-08, 'grow_policy': 'lossguide', 'min_child_weight': 99, 'subsample': 0.9370035262634554, 'colsample_bytree': 0.5829858934827857, 'colsample_bylevel': 0.8422273611850605, 'colsample_bynode': 0.8702038651870093, 'max_bin': 772, 'scale_pos_weight': 9.952867021667055}. Best is trial 38 with value: 15677.0.
# [I 2024-07-12 17:59:02,633] Trial 39 finished with value: 21598.0 and parameters: {'lambda': 0.0011688606347171565, 'alpha': 3.00874328163328e-08, 'max_depth': 14, 'eta': 0.00042324515114193734, 'gamma': 2.848381975821373e-08, 'grow_policy': 'lossguide', 'min_child_weight': 100, 'subsample': 0.83646904901974, 'colsample_bytree': 0.6352035235783812, 'colsample_bylevel': 0.7640664046336364, 'colsample_bynode': 0.9195803007440193, 'max_bin': 763, 'scale_pos_weight': 5.665281896486097}. Best is trial 38 with value: 15677.0.
# [I 2024-07-12 17:59:15,541] Trial 40 finished with value: 30824.0 and parameters: {'lambda': 0.00022036012335736142, 'alpha': 0.00023090962562088838, 'max_depth': 12, 'eta': 0.024812580324198637, 'gamma': 0.7103815964385595, 'grow_policy': 'depthwise', 'min_child_weight': 95, 'subsample': 0.9597459057157023, 'colsample_bytree': 0.6729069848506557, 'colsample_bylevel': 0.7132083381168259, 'colsample_bynode': 0.8676306942127449, 'max_bin': 980, 'scale_pos_weight': 2.4399949214572327}. Best is trial 38 with value: 15677.0.
# [I 2024-07-12 17:59:27,945] Trial 41 finished with value: 15570.0 and parameters: {'lambda': 1.7713359682564997e-05, 'alpha': 0.11307908218307208, 'max_depth': 10, 'eta': 0.014761285262048328, 'gamma': 1.5650433075859632e-07, 'grow_policy': 'lossguide', 'min_child_weight': 86, 'subsample': 0.9298085758532546, 'colsample_bytree': 0.5675727730494318, 'colsample_bylevel': 0.8401594632445628, 'colsample_bynode': 0.8238995876674057, 'max_bin': 714, 'scale_pos_weight': 9.862185850182364}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 17:59:40,729] Trial 42 finished with value: 23849.0 and parameters: {'lambda': 3.2364385096708266e-07, 'alpha': 0.07669850170656832, 'max_depth': 12, 'eta': 0.019771484862874684, 'gamma': 7.02522115100102e-08, 'grow_policy': 'lossguide', 'min_child_weight': 84, 'subsample': 0.9417667778567469, 'colsample_bytree': 0.5816552220182762, 'colsample_bylevel': 0.8222385302653525, 'colsample_bynode': 0.8265487551870726, 'max_bin': 816, 'scale_pos_weight': 4.136725222824507}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 17:59:53,173] Trial 43 finished with value: 17734.0 and parameters: {'lambda': 1.827760093291779e-05, 'alpha': 3.3452412276626373e-07, 'max_depth': 10, 'eta': 0.03758954730499531, 'gamma': 1.121824767956565e-08, 'grow_policy': 'lossguide', 'min_child_weight': 76, 'subsample': 0.8733829800677387, 'colsample_bytree': 0.5262030528886542, 'colsample_bylevel': 0.8434045058791174, 'colsample_bynode': 0.7673508849835191, 'max_bin': 707, 'scale_pos_weight': 6.195928444154626}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:00:04,239] Trial 44 finished with value: 17497.0 and parameters: {'lambda': 5.184322593247902e-06, 'alpha': 2.755808952119537, 'max_depth': 9, 'eta': 0.05445145727127366, 'gamma': 1.769667188088904e-07, 'grow_policy': 'lossguide', 'min_child_weight': 92, 'subsample': 0.9766501806070487, 'colsample_bytree': 0.6011784651586525, 'colsample_bylevel': 0.787396736252848, 'colsample_bynode': 0.8634453429256169, 'max_bin': 695, 'scale_pos_weight': 6.571356813250481}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:00:15,847] Trial 45 finished with value: 15812.0 and parameters: {'lambda': 0.0003813329989727349, 'alpha': 0.6379520915716316, 'max_depth': 14, 'eta': 0.008003129451696614, 'gamma': 1.1011311691860915e-06, 'grow_policy': 'lossguide', 'min_child_weight': 96, 'subsample': 0.8926405006275878, 'colsample_bytree': 0.5285408410695711, 'colsample_bylevel': 0.8105846920351871, 'colsample_bynode': 0.8266817359116143, 'max_bin': 769, 'scale_pos_weight': 9.907015259667231}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:00:26,635] Trial 46 finished with value: 28712.0 and parameters: {'lambda': 0.0027190210792231353, 'alpha': 0.9952513948684382, 'max_depth': 17, 'eta': 0.008851428253634244, 'gamma': 1.2208886686609538e-06, 'grow_policy': 'lossguide', 'min_child_weight': 100, 'subsample': 0.9421384345147998, 'colsample_bytree': 0.5252753377518506, 'colsample_bylevel': 0.8077100043748849, 'colsample_bynode': 0.7501175596886023, 'max_bin': 634, 'scale_pos_weight': 3.526911429356955}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:00:37,132] Trial 47 finished with value: 80000.0 and parameters: {'lambda': 0.00031900602813307897, 'alpha': 0.008130212359492168, 'max_depth': 14, 'eta': 0.016414064748358614, 'gamma': 1.8560777473637344e-07, 'grow_policy': 'lossguide', 'min_child_weight': 43, 'subsample': 0.8973845255277557, 'colsample_bytree': 0.5279188832549356, 'colsample_bylevel': 0.7128408424850924, 'colsample_bynode': 0.9294976275509046, 'max_bin': 776, 'scale_pos_weight': 0.06449112967012086}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:00:47,405] Trial 48 finished with value: 35006.0 and parameters: {'lambda': 8.941752786623135e-06, 'alpha': 4.1281548182786745, 'max_depth': 16, 'eta': 0.029095174806142102, 'gamma': 5.758340157832334e-06, 'grow_policy': 'lossguide', 'min_child_weight': 70, 'subsample': 0.9345738103324326, 'colsample_bytree': 0.5815266438202027, 'colsample_bylevel': 0.7721063050524226, 'colsample_bynode': 0.7787836089713921, 'max_bin': 901, 'scale_pos_weight': 1.946505860999307}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:01:00,770] Trial 49 finished with value: 18126.0 and parameters: {'lambda': 2.0854600765048174e-06, 'alpha': 0.0010121708693350113, 'max_depth': 13, 'eta': 0.009151033408669884, 'gamma': 2.136186885102162e-05, 'grow_policy': 'lossguide', 'min_child_weight': 84, 'subsample': 0.9605028188438245, 'colsample_bytree': 0.549278671331017, 'colsample_bylevel': 0.8101297978288846, 'colsample_bynode': 0.8177055124406063, 'max_bin': 659, 'scale_pos_weight': 7.083883043145789}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:01:13,303] Trial 50 finished with value: 22286.0 and parameters: {'lambda': 5.295829599041556e-07, 'alpha': 0.08731481298622547, 'max_depth': 19, 'eta': 0.00551818141843667, 'gamma': 9.684559083205982e-07, 'grow_policy': 'lossguide', 'min_child_weight': 96, 'subsample': 0.7981609438297529, 'colsample_bytree': 0.6194495123314457, 'colsample_bylevel': 0.8613147645506452, 'colsample_bynode': 0.8486071602839126, 'max_bin': 254, 'scale_pos_weight': 5.069009637974137}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:01:26,017] Trial 51 finished with value: 16394.0 and parameters: {'lambda': 0.0007666279966802813, 'alpha': 0.4107317537799026, 'max_depth': 11, 'eta': 0.002955721772634985, 'gamma': 6.531989806839928e-08, 'grow_policy': 'lossguide', 'min_child_weight': 88, 'subsample': 0.8676886890458474, 'colsample_bytree': 0.7779428078354647, 'colsample_bylevel': 0.8504631406191218, 'colsample_bynode': 0.8826877576979381, 'max_bin': 765, 'scale_pos_weight': 9.182298467894974}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:01:39,944] Trial 52 finished with value: 16105.0 and parameters: {'lambda': 0.00015739888278414028, 'alpha': 0.029576550861643486, 'max_depth': 15, 'eta': 0.003358849392673664, 'gamma': 1.9822141670578007e-08, 'grow_policy': 'lossguide', 'min_child_weight': 82, 'subsample': 0.8992325124871764, 'colsample_bytree': 0.6426423102994978, 'colsample_bylevel': 0.8790666655754599, 'colsample_bynode': 0.8379640850370376, 'max_bin': 818, 'scale_pos_weight': 9.96988235111715}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:01:53,291] Trial 53 finished with value: 19596.0 and parameters: {'lambda': 0.00017284173320118785, 'alpha': 0.02927212170602377, 'max_depth': 14, 'eta': 0.0009721120613096016, 'gamma': 1.1525136989875593e-07, 'grow_policy': 'lossguide', 'min_child_weight': 82, 'subsample': 0.9096722450829048, 'colsample_bytree': 0.5913390335629247, 'colsample_bylevel': 0.8878470927153701, 'colsample_bynode': 0.816407643216418, 'max_bin': 831, 'scale_pos_weight': 6.5759386567764615}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:02:05,632] Trial 54 finished with value: 16026.0 and parameters: {'lambda': 2.7661734744770232e-05, 'alpha': 0.7126603602111339, 'max_depth': 16, 'eta': 0.002117068845740621, 'gamma': 2.2495376567249541e-07, 'grow_policy': 'lossguide', 'min_child_weight': 77, 'subsample': 0.8391267531182681, 'colsample_bytree': 0.64001741054152, 'colsample_bylevel': 0.8734011642189653, 'colsample_bynode': 0.9063830377399564, 'max_bin': 744, 'scale_pos_weight': 9.990980044145461}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:02:14,914] Trial 55 finished with value: 80000.0 and parameters: {'lambda': 2.4355696693666858e-05, 'alpha': 0.8953175302273861, 'max_depth': 17, 'eta': 0.002269425920512078, 'gamma': 3.5198237580777315e-06, 'grow_policy': 'lossguide', 'min_child_weight': 63, 'subsample': 0.8437028533533752, 'colsample_bytree': 0.5645721163084813, 'colsample_bylevel': 0.7354314140307765, 'colsample_bynode': 0.9068870932372353, 'max_bin': 728, 'scale_pos_weight': 0.01046426204001033}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:02:27,437] Trial 56 finished with value: 22317.0 and parameters: {'lambda': 8.432806875853719e-06, 'alpha': 6.22731566541911e-05, 'max_depth': 15, 'eta': 0.09424523797662142, 'gamma': 2.7373346547460286e-07, 'grow_policy': 'lossguide', 'min_child_weight': 76, 'subsample': 0.8054325306166377, 'colsample_bytree': 0.6812201322890326, 'colsample_bylevel': 0.9011869951596507, 'colsample_bynode': 0.9467957818575856, 'max_bin': 682, 'scale_pos_weight': 2.9882678446223276}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:02:40,077] Trial 57 finished with value: 23489.0 and parameters: {'lambda': 2.6710338644840695e-05, 'alpha': 0.11442796563091708, 'max_depth': 18, 'eta': 0.001783601864842545, 'gamma': 5.3359375927251446e-08, 'grow_policy': 'depthwise', 'min_child_weight': 96, 'subsample': 0.7695448407006045, 'colsample_bytree': 0.6231305403206281, 'colsample_bylevel': 0.8227601804432532, 'colsample_bynode': 0.8798941429705989, 'max_bin': 608, 'scale_pos_weight': 5.01374885928358}. Best is trial 41 with value: 15570.0.
# [I 2024-07-12 18:02:51,466] Trial 58 finished with value: 18645.0 and parameters: {'lambda': 0.01049498573969506, 'alpha': 4.467807152817335, 'max_depth': 13, 'eta': 0.008082513451107566, 'gamma': 1.4733710099082672e-06, 'grow_policy': 'lossguide', 'min_child_weight': 69, 'subsample': 0.656886539412515, 'colsample_bytree': 0.5248109858557123, 'colsample_bylevel': 0.8583104438460881, 'colsample_bynode': 0.989274823139866, 'max_bin': 742, 'scale_pos_weight': 7.401153776747519}. Best is trial 41 with value: 15570.0.
# Sem novas melhorias a partir da iteração 59
# Melhor score: 15570.0

# %%
# Salvando as melhores configurações
with open('./artefatos/XGBM/XGBM_best_config.pkl', 'wb') as f:
    pickle.dump(best, f)

# %% [markdown]
# > GradientBoosting Classifier

# %%
import optuna
from sklearn.model_selection import StratifiedKFold

EARLY_STOPPING = 15

class EarlyStoppingExceeded(optuna.exceptions.OptunaError):
    early_stop = EARLY_STOPPING
    early_stop_count = 0
    best_score = None

def early_stopping_opt(study, trial):
    if EarlyStoppingExceeded.best_score == None:
      EarlyStoppingExceeded.best_score = study.best_value

    if study.best_value < EarlyStoppingExceeded.best_score:
        EarlyStoppingExceeded.best_score = study.best_value
        EarlyStoppingExceeded.early_stop_count = 0
    else:
      if EarlyStoppingExceeded.early_stop_count > EarlyStoppingExceeded.early_stop:
            EarlyStoppingExceeded.early_stop_count = 0
            best_score = None
            raise EarlyStoppingExceeded()
      else:
            EarlyStoppingExceeded.early_stop_count=EarlyStoppingExceeded.early_stop_count+1
    return

def objective(trial):
    # Var. de controle da métrica
    avg_loss_func = 0

    # Criando os parametros a serem testados
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-4, 4e-1, log=True),
        "n_estimators": trial.suggest_int("n_estimators", 50, 1000),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 100),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 100),
        "min_weight_fraction_leaf": trial.suggest_float("min_weight_fraction_leaf", 0.0, 0.5),
        "max_depth": trial.suggest_int("max_depth", 3, 20),
        "min_impurity_decrease": trial.suggest_float("min_impurity_decrease", 0.0, 1.0),
        "max_features": trial.suggest_float("max_features", 0.1, 1.0),
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 10, 1000),
        "validation_fraction": trial.suggest_float("validation_fraction", 0.1, 0.5),
        "n_iter_no_change": trial.suggest_int("n_iter_no_change", 5, 20),
    }

    # Fazendo os Splits (Cross Validation)
    cv = StratifiedKFold(n_splits= 5, random_state= 1, shuffle= True)

    for train_idx, validation_idx in cv.split(X_train, y_train):
        # Instancia o Modelo
        model = GradientBoostingClassifier(**params, random_state= 2)

        # Vars Preditoras - Treino
        X_train_cv = X_train.iloc[train_idx]

        # Vars Preditoras - Validação
        X_validation_cv = X_train.iloc[validation_idx]

        # Target - Treino
        y_train_cv = y_train.iloc[train_idx]

        # Target - Validação
        y_validation_cv = y_train.iloc[validation_idx]

        # Aplicando o DATAPREP nos conjuntos de Treino
        X_train_cv_processed = pd.DataFrame(
            data = dp_boost_pipeline.fit_transform(X_train_cv, y_train_cv),
            columns = dp_boost_vars # Lista de variáveis que saem do pipeline na etapa de dataprep
        )[selected_features] # Filtrando apenas as features da etapa de feature selection

        # Aplicando o DATAPREP nos conjuntos de Validação
        X_validation_cv_processed = pd.DataFrame(
            data = dp_boost_pipeline.transform(X_validation_cv),
            columns= dp_boost_vars
        )[selected_features]

        # Treinando o Modelo
        model.fit(X_train_cv_processed, y_train_cv)

        # Fazendo as predições
        y_pred = model.predict(X_validation_cv_processed)

        avg_loss_func += functions.loss_function(y_validation_cv, y_pred)
    
    return avg_loss_func/5

study = optuna.create_study(
    direction= 'minimize',
    study_name= 'GradBoostingClassifier_v01',
    storage= 'sqlite:///GradBoostingClassifier_v01.db'
)

try:
    study.optimize(objective, timeout=7200, callbacks= [early_stopping_opt])

except EarlyStoppingExceeded:
    print(f'Sem novas melhorias a partir da iteração {len(study.trials)}')

best = study.best_trial

print(f'Melhor score: {best.value}')
# Out:
# [I 2024-07-12 18:02:51,635] A new study created in RDB with name: GradBoostingClassifier_v01
# [I 2024-07-12 18:03:55,382] Trial 0 finished with value: 80000.0 and parameters: {'learning_rate': 0.011134399022711591, 'n_estimators': 929, 'min_samples_split': 52, 'min_samples_leaf': 81, 'min_weight_fraction_leaf': 0.16536805573186908, 'max_depth': 4, 'min_impurity_decrease': 0.49603468861177324, 'max_features': 0.738324758973326, 'max_leaf_nodes': 318, 'validation_fraction': 0.2731717084357926, 'n_iter_no_change': 17}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:04:16,431] Trial 1 finished with value: 80000.0 and parameters: {'learning_rate': 0.00011742360349010136, 'n_estimators': 91, 'min_samples_split': 38, 'min_samples_leaf': 79, 'min_weight_fraction_leaf': 0.0879395377047586, 'max_depth': 13, 'min_impurity_decrease': 0.8756415120040659, 'max_features': 0.990612707608473, 'max_leaf_nodes': 396, 'validation_fraction': 0.4467801733819773, 'n_iter_no_change': 18}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:04:30,263] Trial 2 finished with value: 80000.0 and parameters: {'learning_rate': 0.20877811085088235, 'n_estimators': 874, 'min_samples_split': 85, 'min_samples_leaf': 46, 'min_weight_fraction_leaf': 0.1897887108691938, 'max_depth': 17, 'min_impurity_decrease': 0.13362753674607153, 'max_features': 0.8766590277317325, 'max_leaf_nodes': 863, 'validation_fraction': 0.37005382792994, 'n_iter_no_change': 13}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:06:36,706] Trial 3 finished with value: 80000.0 and parameters: {'learning_rate': 0.00035947185774540263, 'n_estimators': 746, 'min_samples_split': 48, 'min_samples_leaf': 13, 'min_weight_fraction_leaf': 0.26350844863890444, 'max_depth': 6, 'min_impurity_decrease': 0.7236035863887105, 'max_features': 0.9416692397969899, 'max_leaf_nodes': 430, 'validation_fraction': 0.2751105088959529, 'n_iter_no_change': 9}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:07:28,543] Trial 4 finished with value: 80000.0 and parameters: {'learning_rate': 0.0018552825581952005, 'n_estimators': 425, 'min_samples_split': 59, 'min_samples_leaf': 73, 'min_weight_fraction_leaf': 0.058166968558957366, 'max_depth': 12, 'min_impurity_decrease': 0.3731575360385583, 'max_features': 0.5031866560009035, 'max_leaf_nodes': 569, 'validation_fraction': 0.4082554122549571, 'n_iter_no_change': 20}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:07:54,356] Trial 5 finished with value: 80000.0 and parameters: {'learning_rate': 0.0003271613952980212, 'n_estimators': 983, 'min_samples_split': 88, 'min_samples_leaf': 81, 'min_weight_fraction_leaf': 0.3570022257973669, 'max_depth': 10, 'min_impurity_decrease': 0.13405183574023705, 'max_features': 0.5469546595334949, 'max_leaf_nodes': 641, 'validation_fraction': 0.11683756486168417, 'n_iter_no_change': 11}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:08:30,310] Trial 6 finished with value: 80000.0 and parameters: {'learning_rate': 0.0007574073878392077, 'n_estimators': 707, 'min_samples_split': 8, 'min_samples_leaf': 36, 'min_weight_fraction_leaf': 0.3056414975891577, 'max_depth': 3, 'min_impurity_decrease': 0.34651525351639256, 'max_features': 0.23229378169305737, 'max_leaf_nodes': 247, 'validation_fraction': 0.31462803754015733, 'n_iter_no_change': 12}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:09:09,188] Trial 7 finished with value: 80000.0 and parameters: {'learning_rate': 0.00015994236350880722, 'n_estimators': 947, 'min_samples_split': 30, 'min_samples_leaf': 66, 'min_weight_fraction_leaf': 0.34047849444026546, 'max_depth': 11, 'min_impurity_decrease': 0.3903928115488896, 'max_features': 0.6960560252738318, 'max_leaf_nodes': 184, 'validation_fraction': 0.4764767764933061, 'n_iter_no_change': 17}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:10:07,785] Trial 8 finished with value: 80000.0 and parameters: {'learning_rate': 0.007144370780206284, 'n_estimators': 505, 'min_samples_split': 11, 'min_samples_leaf': 34, 'min_weight_fraction_leaf': 0.4108727076497595, 'max_depth': 4, 'min_impurity_decrease': 0.4463092350172454, 'max_features': 0.9460820605000559, 'max_leaf_nodes': 977, 'validation_fraction': 0.27285617304367515, 'n_iter_no_change': 7}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:10:25,609] Trial 9 finished with value: 80000.0 and parameters: {'learning_rate': 0.004517946701703111, 'n_estimators': 83, 'min_samples_split': 100, 'min_samples_leaf': 18, 'min_weight_fraction_leaf': 0.11708693861724156, 'max_depth': 3, 'min_impurity_decrease': 0.6216990544530125, 'max_features': 0.5338392616973763, 'max_leaf_nodes': 294, 'validation_fraction': 0.19893714938528412, 'n_iter_no_change': 17}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:10:39,475] Trial 10 finished with value: 80000.0 and parameters: {'learning_rate': 0.0533731474343278, 'n_estimators': 301, 'min_samples_split': 66, 'min_samples_leaf': 92, 'min_weight_fraction_leaf': 0.18008500465962743, 'max_depth': 8, 'min_impurity_decrease': 0.9890287841987899, 'max_features': 0.3007913692317769, 'max_leaf_nodes': 79, 'validation_fraction': 0.1621752894876725, 'n_iter_no_change': 15}. Best is trial 0 with value: 80000.0.
# [I 2024-07-12 18:11:00,778] Trial 11 finished with value: 54329.0 and parameters: {'learning_rate': 0.019068271876710497, 'n_estimators': 66, 'min_samples_split': 37, 'min_samples_leaf': 99, 'min_weight_fraction_leaf': 0.0005124931541443944, 'max_depth': 15, 'min_impurity_decrease': 0.8905455607232611, 'max_features': 0.7357719817908625, 'max_leaf_nodes': 372, 'validation_fraction': 0.46553941410882754, 'n_iter_no_change': 20}. Best is trial 11 with value: 54329.0.
# [I 2024-07-12 18:11:41,080] Trial 12 finished with value: 41436.0 and parameters: {'learning_rate': 0.023963434237547238, 'n_estimators': 269, 'min_samples_split': 24, 'min_samples_leaf': 100, 'min_weight_fraction_leaf': 0.014256327199374863, 'max_depth': 17, 'min_impurity_decrease': 0.6817500742353352, 'max_features': 0.7313451358414178, 'max_leaf_nodes': 37, 'validation_fraction': 0.3579093180212791, 'n_iter_no_change': 20}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:12:10,171] Trial 13 finished with value: 47876.0 and parameters: {'learning_rate': 0.037779917761123626, 'n_estimators': 246, 'min_samples_split': 24, 'min_samples_leaf': 97, 'min_weight_fraction_leaf': 0.01795568244815914, 'max_depth': 20, 'min_impurity_decrease': 0.7459105956183654, 'max_features': 0.7293555079834025, 'max_leaf_nodes': 19, 'validation_fraction': 0.3631145258416822, 'n_iter_no_change': 20}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:12:20,505] Trial 14 finished with value: 80000.0 and parameters: {'learning_rate': 0.0651412613058989, 'n_estimators': 273, 'min_samples_split': 21, 'min_samples_leaf': 100, 'min_weight_fraction_leaf': 0.49341261140911225, 'max_depth': 20, 'min_impurity_decrease': 0.6858583769186799, 'max_features': 0.6724389041366812, 'max_leaf_nodes': 30, 'validation_fraction': 0.351055351868061, 'n_iter_no_change': 5}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:12:31,441] Trial 15 finished with value: 44290.0 and parameters: {'learning_rate': 0.29331147293072485, 'n_estimators': 255, 'min_samples_split': 2, 'min_samples_leaf': 61, 'min_weight_fraction_leaf': 0.01654882749900563, 'max_depth': 19, 'min_impurity_decrease': 0.7734643092436262, 'max_features': 0.38792832955631795, 'max_leaf_nodes': 119, 'validation_fraction': 0.39538374162896706, 'n_iter_no_change': 20}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:12:40,683] Trial 16 finished with value: 80000.0 and parameters: {'learning_rate': 0.3907573756668431, 'n_estimators': 400, 'min_samples_split': 3, 'min_samples_leaf': 59, 'min_weight_fraction_leaf': 0.11983368684460746, 'max_depth': 17, 'min_impurity_decrease': 0.583711144166479, 'max_features': 0.4026365107472541, 'max_leaf_nodes': 141, 'validation_fraction': 0.40267842212223975, 'n_iter_no_change': 15}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:12:50,612] Trial 17 finished with value: 58379.0 and parameters: {'learning_rate': 0.1411824155726685, 'n_estimators': 185, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.043221632250717956, 'max_depth': 17, 'min_impurity_decrease': 0.8020919237862709, 'max_features': 0.11652891794039016, 'max_leaf_nodes': 703, 'validation_fraction': 0.3173184688268854, 'n_iter_no_change': 15}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:13:02,156] Trial 18 finished with value: 80000.0 and parameters: {'learning_rate': 0.10839867599170504, 'n_estimators': 604, 'min_samples_split': 2, 'min_samples_leaf': 55, 'min_weight_fraction_leaf': 0.23162200323049525, 'max_depth': 15, 'min_impurity_decrease': 0.2520576955135275, 'max_features': 0.40620116424184693, 'max_leaf_nodes': 151, 'validation_fraction': 0.4275889836377429, 'n_iter_no_change': 18}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:13:29,619] Trial 19 finished with value: 70738.0 and parameters: {'learning_rate': 0.024828966014600544, 'n_estimators': 372, 'min_samples_split': 19, 'min_samples_leaf': 42, 'min_weight_fraction_leaf': 0.08118883446003401, 'max_depth': 19, 'min_impurity_decrease': 0.6029660286799104, 'max_features': 0.42391352516059777, 'max_leaf_nodes': 222, 'validation_fraction': 0.20772040188909138, 'n_iter_no_change': 19}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:13:38,424] Trial 20 finished with value: 80000.0 and parameters: {'learning_rate': 0.37226353350133745, 'n_estimators': 199, 'min_samples_split': 37, 'min_samples_leaf': 27, 'min_weight_fraction_leaf': 0.1349556611671781, 'max_depth': 15, 'min_impurity_decrease': 0.9968650243458678, 'max_features': 0.6298870384806641, 'max_leaf_nodes': 471, 'validation_fraction': 0.4981209549906137, 'n_iter_no_change': 14}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:14:11,507] Trial 21 finished with value: 43924.0 and parameters: {'learning_rate': 0.02899539282284069, 'n_estimators': 213, 'min_samples_split': 21, 'min_samples_leaf': 90, 'min_weight_fraction_leaf': 0.01572800605720109, 'max_depth': 20, 'min_impurity_decrease': 0.7652857409016002, 'max_features': 0.8283144157986075, 'max_leaf_nodes': 23, 'validation_fraction': 0.3719206173117824, 'n_iter_no_change': 20}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:15:02,603] Trial 22 finished with value: 80000.0 and parameters: {'learning_rate': 0.004304558035603392, 'n_estimators': 172, 'min_samples_split': 28, 'min_samples_leaf': 90, 'min_weight_fraction_leaf': 0.009787282115651238, 'max_depth': 18, 'min_impurity_decrease': 0.830200396484504, 'max_features': 0.837050388764876, 'max_leaf_nodes': 91, 'validation_fraction': 0.3865363717768215, 'n_iter_no_change': 19}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:15:42,750] Trial 23 finished with value: 63206.0 and parameters: {'learning_rate': 0.019900358856772844, 'n_estimators': 329, 'min_samples_split': 11, 'min_samples_leaf': 88, 'min_weight_fraction_leaf': 0.055550857562714176, 'max_depth': 19, 'min_impurity_decrease': 0.681901451860329, 'max_features': 0.8088993517057783, 'max_leaf_nodes': 13, 'validation_fraction': 0.3480772514544578, 'n_iter_no_change': 18}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:15:54,284] Trial 24 finished with value: 70833.0 and parameters: {'learning_rate': 0.08180136991640395, 'n_estimators': 542, 'min_samples_split': 18, 'min_samples_leaf': 68, 'min_weight_fraction_leaf': 0.0821737594047701, 'max_depth': 16, 'min_impurity_decrease': 0.7912676214539238, 'max_features': 0.2975832692811815, 'max_leaf_nodes': 115, 'validation_fraction': 0.3406249549345646, 'n_iter_no_change': 16}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:17:40,935] Trial 25 finished with value: 64717.0 and parameters: {'learning_rate': 0.0019082170709704336, 'n_estimators': 466, 'min_samples_split': 32, 'min_samples_leaf': 86, 'min_weight_fraction_leaf': 0.0007128819083744402, 'max_depth': 19, 'min_impurity_decrease': 0.5492542681216196, 'max_features': 0.5981687789271706, 'max_leaf_nodes': 218, 'validation_fraction': 0.42514688635876974, 'n_iter_no_change': 20}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:18:14,239] Trial 26 finished with value: 80000.0 and parameters: {'learning_rate': 0.011292134591706174, 'n_estimators': 136, 'min_samples_split': 46, 'min_samples_leaf': 63, 'min_weight_fraction_leaf': 0.041630653918838495, 'max_depth': 20, 'min_impurity_decrease': 0.903847927339682, 'max_features': 0.8229208009374916, 'max_leaf_nodes': 86, 'validation_fraction': 0.29988904976820874, 'n_iter_no_change': 19}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:18:24,222] Trial 27 finished with value: 80000.0 and parameters: {'learning_rate': 0.17414895830042718, 'n_estimators': 239, 'min_samples_split': 8, 'min_samples_leaf': 74, 'min_weight_fraction_leaf': 0.14784588536513335, 'max_depth': 14, 'min_impurity_decrease': 0.6458781357011583, 'max_features': 0.49000041123462773, 'max_leaf_nodes': 307, 'validation_fraction': 0.389941131315283, 'n_iter_no_change': 10}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:19:14,954] Trial 28 finished with value: 57390.0 and parameters: {'learning_rate': 0.03589409654631401, 'n_estimators': 358, 'min_samples_split': 25, 'min_samples_leaf': 51, 'min_weight_fraction_leaf': 0.09265582799405755, 'max_depth': 18, 'min_impurity_decrease': 0.018368373164351137, 'max_features': 0.6046222989580148, 'max_leaf_nodes': 145, 'validation_fraction': 0.44060480828103277, 'n_iter_no_change': 16}. Best is trial 12 with value: 41436.0.
# [I 2024-07-12 18:19:40,924] Trial 29 finished with value: 80000.0 and parameters: {'learning_rate': 0.009433494453834915, 'n_estimators': 136, 'min_samples_split': 55, 'min_samples_leaf': 82, 'min_weight_fraction_leaf': 0.21617790073538476, 'max_depth': 18, 'min_impurity_decrease': 0.49343466639383593, 'max_features': 0.771447447182546, 'max_leaf_nodes': 261, 'validation_fraction': 0.2502305798314406, 'n_iter_no_change': 17}. Best is trial 12 with value: 41436.0.
# Sem novas melhorias a partir da iteração 30
# Melhor score: 41436.0

# %%
# Salvando as melhores configurações
with open('./artefatos/GBM/GBM_best_config.pkl', 'wb') as f:
    pickle.dump(best, f)
